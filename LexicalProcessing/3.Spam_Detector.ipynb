# %% [markdown]
# ##  Building a Spam Detector - I
# You’ve learnt all the basic preprocessing steps required for most text analytics applications. In this section, you will learn how to apply these steps to build a spam detector.
#
#
#
# Until now, you had learnt how to use the scikit-learn library to train machine learning algorithms. Here, Krishna will demonstrate how to build a spam detector using NLTK library which is, as you might have already realised, is your go-to tool when you’re working with text.
#
#
#
# Now, it is not necessary for you to learn how to use NLTK’s machine learning functions. But it’s always nice to have knowledge of more than one tool. More importantly, he’ll demonstrate how to extract features from the raw text without using the scikit-learn package. So take this demonstration as a bonus as you'll learn how to preprocess text and build a classifier using NLTK. Before getting started, download the Jupyter notebook provided below to follow along:

# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
spam = pd.read_csv("Data/SMSSpamCollection.txt", sep = "\t", names=["label", "message"])

# %%
print(spam.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
print(spam['message'][2])
# Out:
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[0])
# Out:
# (['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham')

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# Words less than a certain threshold are removed to eliminate special characters such as double exclamation marks, or double dots (the period character). And you won’t lose any information by doing this because there are no words less than two characters other than some stopwords (such as ‘am’, ‘is’, etc.).
#
#
#
# You’ve already learnt how to create a bag-of-words model by using the NLTK’s CountVectorizer function. However, Krishna will demonstrate how to build a bag-of-words model without using the NLTK function, that is, building the model manually. The first step towards achieving that goal is to create a vocabulary from the text corpus that you have. In the following video, you’re going to learn how to create vocabulary from the dataset.

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):
    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8393

# %%
word_features
# Out:
# dict_keys(['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', 'lar', 'joke', 'wif', 'oni', 'free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18', 'dun', 'say', 'early', 'hor', 'already', 'nah', "n't", 'think', 'usf', 'live', 'around', 'though', 'freemsg', 'hey', 'darling', 'week', 'word', 'back', 'like', 'fun', 'still', 'xxx', 'chgs', 'send', '£1.50', 'rcv', 'even', 'brother', 'speak', 'treat', 'aid', 'patent', 'per', 'request', "'melle", 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'callers', 'press', 'copy', 'friends', 'winner', 'value', 'network', 'customer', 'select', 'receivea', '£900', 'prize', 'reward', 'claim', 'call', '09061701461.', 'code', 'kl341', 'valid', 'hours', 'mobile', 'months', 'entitle', 'update', 'latest', 'colour', 'mobiles', 'camera', '08002986030', 'gon', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', "'ve", 'cry', 'enough', 'today', 'six', 'chance', 'cash', '100', '20,000', 'pound', 'csh11', '87575.', 'cost', '150p/day', '6days', '16+', 'tsandcs', 'reply', 'info', 'urgent', 'membership', '£100,000', 'jackpot', '81010', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18', 'search', 'right', 'thank', 'breather', 'promise', 'wont', 'take', 'help', 'grant', 'fulfil', 'wonderful', 'bless', 'time', 'date', 'sunday', 'xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'next', 'message', 'http', '//wap', 'xxxmobilemovieclub.com', 'n=qjkgighjjgcbl', 'watch', 'remember', 'spell', 'name', 'yes', 'naughty', 'make', 'wet', 'fine', 'that\x92s', 'way', 'feel', 'gota', 'england', 'macedonia', 'dont', 'miss', 'goals/team', 'news', 'national', 'team', '87077', 'try', 'wales', 'scotland', '4txt/ú1.20', 'poboxox36504w45wq', 'seriously', 'pay', 'first', 'stock', 'comin', 'aft', 'finish', 'lunch', 'str', 'lor', 'ard', 'smth', 'ffffffffff', 'alright', 'meet', 'sooner', 'force', 'eat', 'slice', 'really', 'hungry', 'tho', 'suck', 'mark', 'worry', 'know', 'sick', 'turn', 'pizza', 'lol', 'always', 'convince', 'catch', 'bus', 'fry', 'egg', 'tea', 'mom', 'leave', 'dinner', 'love', 'amp', "'re", 'pack', 'car', "'ll", 'let', 'room', 'ahhh', 'work', 'vaguely', 'wait', 'clear', 'sure', 'sarcastic', 'yeah', 'apologetic', 'fall', 'actin', 'spoil', 'child', 'till', 'badly', 'cheer', 'tell', 'anything', 'fear', 'faint', 'housework', 'quick', 'cuppa', 'subscription', 'ringtone', 'charge', '£5/month', 'please', 'confirm', 'yup', 'look', 'msg', 'xuhui', 'learn', '2nd', 'lesson', '8am', 'oops', 'roommate', 'see', 'letter', 'decide', 'hello', 'saturday', 'texting', 'tomo', 'invite', 'pls', 'ahead', 'watts', 'weekend', 'abiola', 'forget', 'need', 'crave', 'sweet', 'arabian', 'steed', 'mmmmmm', 'yummy', '07732584351', 'rodger', 'burn', 'sms', 'nokia', 'camcorder', '08000930705', 'delivery', 'tomorrow', 'hope', 'man', 'well', 'endow', 'inch', 'calls..messages..missed', 'hep', 'immunisation', 'nigeria', 'fair', 'hopefully', 'tyler', 'could', 'maybe', 'ask', 'bite', 'stubborn', 'hospital', 'keep', 'weak', 'sucker', 'hospitals', 'suckers', 'saw', 'class', 'gram', 'usually', 'run', 'half', 'eighth', 'smarter', 'almost', 'whole', 'second', 'fyi', 'ride', 'morning', 'crash', 'place', 'wow', 'never', 'realize', 'embarassed', 'accomodations', 'since', 'best', 'seem', 'happy', 'cave', 'sorry', 'give', 'offer', 'embarassing', 'sptv', 'new', 'jersey', 'devil', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'mallika', 'sherawat', 'yesterday', 'find', 'url', 'congrats', 'year', 'special', 'cinema', 'pass', '09061209465', 'suprman', 'matrix3', 'starwars3', 'etc', 'bx420-ip4-5we', '150pm', 'later', 'reach', 'yes..gauti', 'sehwag', 'odi', 'series', 'pick', 'burger', 'move', 'pain', 'kill', 'good', 'girls', 'situation', 'seekers', 'part', 'check', 'roommates', 'forever', 'come', 'd ...

# %%
print(type(word_features))
# Out:
# <class 'dict_keys'>

# %%
### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))
print(sliceIndex)
# Out:
# 4457

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
print(len(train_messages))
print(len(test_messages))
# Out:
# 4457
# 1115

# %% [markdown]
# You learnt how to create vocabulary manually using all the words in the text corpus. In the next section, you’ll look at how to create a bag-of-words model.
#
# Why do you think that Naive Bayes is a good choice when it comes to text classification problems such as spam detection
#
# Naive Bayes assumes independence between features. Now, in text classification such as spam detection, only the presence of certain words matter. It doesn't matter if they occur before or after certain words. Hence, Naive Bayes often performs very well on these problems.

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
train_messages[1]
# Out:
# (['4mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   '11mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   '08000938767',
#   'update',
#   'or2stoptxt'],
#  'spam')

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
training_set[0]
# Out:
# ({'contains(jurong)': False,
#   'contains(point)': False,
#   'contains(crazy..)': False,
#   'contains(available)': False,
#   'contains(bugis)': False,
#   'contains(great)': False,
#   'contains(world)': False,
#   'contains(buffet)': False,
#   'contains(...)': False,
#   'contains(cine)': False,
#   'contains(get)': False,
#   'contains(amore)': False,
#   'contains(wat)': False,
#   'contains(lar)': False,
#   'contains(joke)': False,
#   'contains(wif)': False,
#   'contains(oni)': False,
#   'contains(free)': False,
#   'contains(entry)': False,
#   'contains(wkly)': False,
#   'contains(comp)': False,
#   'contains(win)': False,
#   'contains(cup)': False,
#   'contains(final)': False,
#   'contains(tkts)': False,
#   'contains(21st)': False,
#   'contains(may)': False,
#   'contains(2005.)': False,
#   'contains(text)': False,
#   'contains(87121)': False,
#   'contains(receive)': False,
#   'contains(question)': False,
#   'contains(std)': False,
#   'contains(txt)': False,
#   'contains(rate)': False,
#   'contains(apply)': False,
#   'contains(08452810075over18)': False,
#   'contains(dun)': False,
#   'contains(say)': False,
#   'contains(early)': False,
#   'contains(hor)': False,
#   'contains(already)': False,
#   'contains(nah)': False,
#   "contains(n't)": False,
#   'contains(think)': False,
#   'contains(usf)': False,
#   'contains(live)': False,
#   'contains(around)': False,
#   'contains(though)': False,
#   'contains(freemsg)': False,
#   'contains(hey)': False,
#   'contains(darling)': False,
#   'contains(week)': False,
#   'contains(word)': False,
#   'contains(back)': False,
#   'contains(like)': False,
#   'contains(fun)': False,
#   'contains(still)': False,
#   'contains(xxx)': False,
#   'contains(chgs)': False,
#   'contains(send)': False,
#   'contains(£1.50)': False,
#   'contains(rcv)': False,
#   'contains(even)': False,
#   'contains(brother)': False,
#   'contains(speak)': False,
#   'contains(treat)': False,
#   'contains(aid)': False,
#   'contains(patent)': False,
#   'contains(per)': False,
#   'contains(request)': False,
#   "contains('melle)": False,
#   'contains(melle)': False,
#   'contains(oru)': False,
#   'contains(minnaminunginte)': False,
#   'contains(nurungu)': False,
#   'contains(vettam)': False,
#   'contains(set)': False,
#   'contains(callertune)': False,
#   'contains(callers)': False,
#   'contains(press)': False,
#   'contains(copy)': False,
#   'contains(friends)': False,
#   'contains(winner)': False,
#   'contains(value)': False,
#   'contains(network)': False,
#   'contains(customer)': False,
#   'contains(select)': False,
#   'contains(receivea)': False,
#   'contains(£900)': False,
#   'contains(prize)': False,
#   'contains(reward)': False,
#   'contains(claim)': False,
#   'contains(call)': False,
#   'contains(09061701461.)': False,
#   'contains(code)': False,
#   'contains(kl341)': False,
#   'contains(valid)': False,
#   'contains(hours)': False,
#   'contains(mobile)': False,
#   'contains(months)': False,
#   'contains(entitle)': False,
#   'contains(update)': False,
#   'contains(latest)': False,
#   'contains(colour)': False,
#   'contains(mobiles)': False,
#   'contains(camera)': False,
#   'contains(08002986030)': False,
#   'contains(gon)': False,
#   'contains(home)': False,
#   'contains(soon)': False,
#   'contains(want)': False,
#   'contains(talk)': False,
#   'contains(stuff)': False,
#   'contains(anymore)': False,
#   'contains(tonight)': False,
#   "contains('ve)": False,
#   'contains(cry)': False,
#   'contains(enough)': False,
#   'contains(today)': False,
#   'contains(six)': False,
#   'contains(chance)': False,
#   'contains(cash)': False,
#   'contains(100)': False,
#   'contains(20,000)': False,
#   'contains(pound)': False,
#   'contains(csh11)': False,
#   'contains(87575.)': False,
#   'contains(cost)': False,
#   'contains(150p/day)': False,
#   'contains(6days)': False,
#   'contains(16+)': False,
#   'contains(tsandcs)': False,
#   'contains(reply)': False,
#   'contains(info)': False,
#   'contains(urgent)': False,
#   'contains(membership)': False,
#   'contains(£100,000)': False,
#   'contains(jackpot)': False,
#   'contains(81010)': False,
#   'contains(www.dbuk.net)': False,
#   'contains(lccltd)': False,
#   'contains(pobox)': False,
#   'contains(4403ldnw1a7rw18)': False,
#   'contains(search)': False,
#   'contains(right)': False,
#   'contains(thank)': False,
#   'contains(breather)': False,
#   'contains(promise)': False,
#   'contains(wont)': False,
#   'contains(take)': False,
#   'contains(help)': False,
#   'contains(grant)': False,
#   'contains(fulfil)': False,
#   'contains(wonderful)': False,
#   'contains(bless)': False,
#   'contains(time)': False,
#   'contains(date)': False,
#   'contains(sunday)': False,
#   'contains(xxxmobilemovieclub)': False,
#   'contains(use)': False,
#   'contains(credit)': False,
#   'contains(click)': False,
#   'contains(wap)': False,
#   'contains(link)': False,
#   'contains(next)': False,
#   'contains(message)': False,
#   'contains(http)': False,
#   'contains(//wap)': False,
#   'contains(xxxmobilemovieclub.com)': False,
#   'contains(n=qjkgighjjgcbl)': False,
#   'contains(watch)': False,
#   'contains(remember)': False,
#   'contains(spell)': False,
#   'contains(name)': False,
#   'contains(yes)': False,
#   'contains(naughty)': False,
#   'contains(make)': False,
#   'contains(wet)': False,
#   'contains(fine)': False,
#   'contains(that\x92s)': False,
#   'contains(way)': False,
#   'contains(feel)': False,
#   'contains(gota)': False,
#   'contains(england)': False,
#   'contains(macedonia)': False,
#   'contains(dont)': False,
#   'contains(miss)': False,
#   'contains(goals/team)': False,
#   'contains(news)': False,
#   'contains(national)': False,
#   'contains(team)': False,
#   'contains(87077)': False,
#   'contains(try)': False,
#   'contains(wales)': False,
#   'contains(scotland)': False,
#   'contains(4txt/ú1.20)': False,
#   'contains(poboxox36504w45wq)': False,
#   'contains(seriously)': False,
#   'contains(pay)': False,
#   'contains(first)': False,
#   'contains(stock)': False,
#   'contains(comin)': False,
#   'contains(aft)': False,
#   'contains(finish)': False,
#   'contains(lunch)': False,
#   'contains(str)': False,
#   'contains(lor)': False,
#   'contains(ard)': False,
#   'contains(smth)': False,
#   'contains(ffffffffff)': False,
#   'contains(alright)': False,
#   'contains(meet)': False,
#   'contains(sooner)': False,
#   'contains(force)': False,
#   'contains(eat)': False,
#   'contains(slice)': False,
#   'contains(really)': False,
#   'contains(hungry)': False,
#   'contains(tho)': False,
#   'contains(suck)': False,
#   'contains(mark)': False,
#   'contains(worry)': False,
#   'contains(know)': False,
#   'contains(sick)': False,
#   'contains(turn)': False,
#   'contains(pizza)': False,
#   'contains(lol)': False,
#   'contains(always)': False,
#   'contains(convince)': False,
#   'contains(catch)': False,
#   'contains(bus)': False,
#   'contains(fry)': False,
#   'contains(egg)': False,
#   'contains(tea)': False,
#   'contains(mom)': False,
#   'contains(leave)': False,
#   'contains(dinner)': False,
#   'contains(love)': True,
#   'contains(amp)': False,
#   "contains('re)": False,
#   'contains(pack)': False,
#   'contains(car)': False,
#   "contains('ll)": False,
#   'contains(let)': False,
#   'contains(room)': False,
#   'contains(ahhh)': False,
#   'contains(work)': False,
#   'contains(vaguely)': False,
#   'contains(wait)': False,
#   'contains(clear)': False,
#   'contains(sure)': False,
#   'contains(sarcastic)': False,
#   'contains(yeah)': False,
#   'contains(apologetic)': False,
#   'contains(fall)': False,
#   'contains(actin)': False,
#   'contains(spoil)': False,
#   'contains(child)': False,
#   'contains(till)': False,
#   'contains(badly)': False,
#   'contains(cheer)': False,
#   'contains(tell)': False,
#   'contains(anything)': False,
#   'contains(fear)': False,
#   'contains(faint)': False,
#   'contains(housework)': False,
#   'contains(quick)': False,
#   'contains(cuppa)': False,
#   'contains(subscription)': False,
#   'contains(ringtone)': False,
#   'contains(charge)': False,
#   'contains(£5/month)': False,
#   'contains(please)': False,
#   'contains(confirm)': False,
#   'contains(yup)': False,
#   'contains(look)': False,
#   'contains(msg)': False,
#   'contains(xuhui)': False,
#   'contains(learn)': False,
#   'contains(2nd)': False,
#   'contains(lesson)': False,
#   'contains(8am)': False,
#   'contains(oops)': False,
#   'contains(roommate)': False,
#   'contains(see)': False,
#   'contains(letter)': False,
#   'contains(decide)': False,
#   'contains(hello)': False,
#   'contains(saturday)': False,
#   'contains(texting)': False,
#   'contains(tomo)': False,
#   'contains(invite)': False,
#   'contains(pls)': False,
#   'contains(ahead)': False,
#   'contains(watts)': False,
#   'contains(weekend)': False,
#   'contains(abiola)': False,
#   'contains(forget)': False,
#   'contains(need)': False,
#   'contains(crave)': False,
#   'contains(sweet)': False,
#   'contains(arabian)': False,
#   'contains(steed)': False,
#   'contains(mmmmmm)': False,
#   'contains(yummy)': False,
#   'contains(07732584351)': False,
#   'contains(rodger)': False,
#   'contains(burn)': False,
#   'contains(sms)': False,
#   'contains(nokia)': False,
#   'contains(camcorder)': False,
#   'contains(08000930705)': False,
#   'contains(delivery)': False,
#   'contains(tomorrow)': False,
#   'contains(hope)': False,
#   'contains(man)': False,
#   'contains(well)': False,
#   'contains(endow)': False,
#   'contains(inch)': False,
#   'contains(calls..messages..missed)': False,
#   'contains(hep)': False,
#   'contains(immunisation)': False,
#   'contains(nigeria)': False,
#   'contains(fair)': False,
#   'contains(hopefully)': False,
#   'contains(tyler)': False,
#   'contains(could)': False,
#   'contains(maybe)': False,
#   'contains(ask)': False,
#   'contains(bite)': False,
#   'contains(stubborn)': False,
#   'contains(hospital)': False,
#   'contains(keep)': False,
#   'contains(weak)': False,
#   'contains(sucker)': False,
#   'contains(hospitals)': False,
#   'contains(suckers)': False,
#   'contains(saw)': False,
#   'contains(class)': False,
#   'contains(gram)': False,
#   'contains(usually)': False,
#   'contains(run)': False,
#   'contains(half)': False,
#   'contains(eighth)': False,
#   'contains(smarter)': False,
#   'contains(almost)': False,
#   'contains(whole)': False,
#   'contains(second)': False,
#   'contains(fyi)': False,
#   'contains(ride)': False,
#   'contains(morning)': False,
#   'contains(crash)': False,
#   'contains(place)': False,
#   'contains(wow)': False,
#   'contains(never)': False,
#   'contains(realize)': False,
#   'contains(embarassed)': False,
#   'contains(accomodations)': False,
#   'contains(since)': False,
#   'contains(best)': False,
#   'contains(seem)': False,
#   'contains(happy)': False,
#   'contains(cave)': False,
#   'contains(sorry)': False,
#   'contains(give)': False,
#   'contains(offer)': False,
#   'contains(embarassing)': False,
#   'contains(sptv)': False,
#   'contains(new)': False,
#   'contains(jersey)': False,
#   'contains(devil)': False,
#   'contains(detroit)': False,
#   'contains(red)': False,
#   'contains(wing)': False,
#   'contains(play)': False,
#   'contains(ice)': False,
#   'contains(hockey)': False,
#   'contains(correct)': False,
#   'contains(incorrect)': False,
#   'contains(end)': False,
#   'contains(mallika)': False,
#   'contains(sherawat)': False,
#   'contains(yesterday)': False,
#   'contains(find)': False,
#   'contains(url)': False,
#   'contains(congrats)': False,
#   'contains(year)': False,
#   'contains(special)': False,
#   'contains(cinema)': False,
#   'contains(pass)': False,
#   'contains(09061209465)': False,
#   'contains(suprman)': False,
#   'contains(matrix3)': False,
#   'contains(starwars3)': False,
#   'contains(etc)': False,
#   'contains(bx420-ip4-5we)': False,
#   'contains(150pm)': False,
#   'contains(later)': False,
#   'contains(reach)': False,
#   'contains(yes..gauti)': False,
#   'contains(sehwag)': False,
#   'contains(odi)': False,
#   'contains(series)': False,
#   'contains(pick)': False,
#   'contains(burger)': False,
#   'contains(move)': False,
#   'contains(pain)': False,
#   'contains(kill)': False,
#   'contains(good)': False,
#   'contains(girls)': False,
#   'contains(situation)': False,
#   'contains(seekers)': False,
#   'contains(part)': False,
#   'contains(check)': False,
#   'contains(roommates)': False,
#   'contains(forever)': False,
#   'contains(come)': False,
#   'contains(double)': False,
#   'contains(hair)': False,
#   'contains(dresser)': False,
#   'contains(wun)': False,
#   'contains(cut)': False,
#   'contains(short)': False,
#   'contains(nice)': False,
#   'contains(advise)': False,
#   'contains(follow)': False,
#   'contains(recent)': False,
#   'contains(review)': False,
#   'contains(mob)': False,
#   'contains(award)': False,
#   'contains(£1500)': False,
#   'contains(bonus)': False,
#   'contains(09066364589)': False,
#   'contains(song)': False,
#   'contains(dedicate)': False,
#   'contains(day..)': False,
#   'contains(valuable)': False,
#   'contains(frnds)': False,
#   'contains(rply)': False,
#   'contains(complimentary)': False,
#   'contains(trip)': False,
#   'contains(eurodisinc)': False,
#   'contains(trav)': False,
#   'contains(aco)': False,
#   'contains(entry41)': False,
#   'contains(£1000)': False,
#   'contains(dis)': False,
#   'contains(18+6*£1.50)': False,
#   'contains(morefrmmob)': False,
#   'contains(shracomorsglsuplt)': False,
#   'contains(ls1)': False,
#   'contains(3aj)': False,
#   'contains(hear)': False,
#   'contains(divorce)': False,
#   'contains(barbie)': False,
#   'contains(ken)': False,
#   'contains(plane)': False,
#   'contains(month)': False,
#   'contains(wah)': False,
#   'contains(lucky)': False,
#   'contains(save)': False,
#   'contains(money)': False,
#   'contains(hee)': False,
#   'contains(babe)': False,
#   'contains(wan)': False,
#   'contains(something)': False,
#   'contains(k..k)': False,
#   'contains(perform)': False,
#   'contains(machan)': False,
#   'contains(thats)': False,
#   'contains(cool)': False,
#   'contains(gentleman)': False,
#   'contains(dignity)': False,
#   'contains(respect)': False,
#   'contains(people)': False,
#   'contains(much)': False,
#   'contains(shy)': False,
#   'contains(operate)': False,
#   'contains(job)': False,
#   'contains(earn)': False,
#   'contains(stop)': False,
#   'contains(urgnt)': False,
#   'contains(real)': False,
#   'contains(ticket)': False,
#   'contains(one)': False,
#   'contains(jacket)': False,
#   'contains(multis)': False,
#   'contains(start)': False,
#   'contains(bed)': False,
#   'contains(coin)': False,
#   'contains(factory)': False,
#   'contains(nitros)': False,
#   'contains(ela)': False,
#   'contains(kano.)': False,
#   'contains(download)': False,
#   'contains(wen)': False,
#   'contains(free..)': False,
#   'contains(stand)': False,
#   'contains(close)': False,
#   'contains(tho-)': False,
#   'contains(another)': False,
#   'contains(night)': False,
#   'contains(spend)': False,
#   'contains(late)': False,
#   'contains(afternoon)': False,
#   'contains(casualty)': False,
#   'contains(mean)': False,
#   'contains(stuff42moro)': False,
#   'contains(include)': False,
#   'contains(sheet)': False,
#   'contains(smile)': False,
#   'contains(pleasure)': False,
#   'contains(trouble)': False,
#   'contains(pour)': False,
#   'contains(rain)': False,
#   'contains(sum1)': False,
#   'contains(hurt)': False,
#   'contains(becoz)': False,
#   'contains(someone)': False,
#   'contains(service)': False,
#   'contains(representative)': False,
#   'contains(0800)': False,
#   'contains(169)': False,
#   'contains(6031)': False,
#   'contains(10am-9pm)': False,
#   'contains(guarantee)': False,
#   'contains(£5000)': False,
#   'contains(havent)': False,
#   'contains(plan)': False,
#   'contains(buy)': False,
#   'contains(lido)': False,
#   'contains(530)': False,
#   'contains(show)': False,
#   'contains(collect)': False,
#   'contains(simply)': False,
#   'contains(password)': False,
#   'contains(mix)': False,
#   'contains(85069)': False,
#   'contains(verify)': False,
#   'contains(usher)': False,
#   'contains(britney)': False,
#   'contains(fml)': False,
#   'contains(box)': False,
#   'contains(5249)': False,
#   'contains(mk17)': False,
#   'contains(92h)': False,
#   'contains(450ppw)': False,
#   'contains(telugu)': False,
#   'contains(movie..wat)': False,
#   'contains(abt)': False,
#   'contains(load)': False,
#   'contains(loan)': False,
#   'contains(hols)': False,
#   'contains(hairdressers)': False,
#   'contains(appointment)': False,
#   'contains(four)': False,
#   'contains(shower)': False,
#   'contains(beforehand)': False,
#   'contains(cause)': False,
#   'contains(prob)': False,
#   'contains(coffee)': False,
#   'contains(animation)': False,
#   'contains(nothing)': False,
#   'contains(else)': False,
#   'contains(okay)': False,
#   'contains(price)': False,
#   'contains(long)': False,
#   'contains(legal)': False,
#   'contains(ave)': False,
#   'contains(ams)': False,
#   'contains(4the)': False,
#   'contains(drive)': False,
#   'contains(test)': False,
#   'contains(yet)': False,
#   'contains(guess)': False,
#   'contains(boston)': False,
#   'contains(men)': False,
#   'contains(change)': False,
#   'contains(location)': False,
#   'contains(nyc)': False,
#   'contains(cuz)': False,
#   'contains(signin)': False,
#   'contains(page)': False,
#   'contains(umma)': False,
#   'contains(life)': False,
#   'contains(vava)': False,
#   'contains(lot)': False,
#   'contains(dear)': False,
#   'contains(wish)': False,
#   'contains(birthday)': False,
#   'contains(truly)': False,
#   'contains(memorable)': False,
#   'contains(aight)': False,
#   'contains(hit)': False,
#   'contains(would)': False,
#   'contains(address)': False,
#   'contains(consider)': False,
#   'contains(computer)': False,
#   'contains(minecraft)': False,
#   'contains(server)': False,
#   'contains(grumpy)': False,
#   'contains(old)': False,
#   'contains(better)': False,
#   'contains(lie)': False,
#   'contains(busy)': False,
#   'contains(plural)': False,
#   'contains(noun)': False,
#   'contains(research)': False,
#   'contains(dinner.msg)': False,
#   'contains(cos)': False,
#   'contains(things)': False,
#   'contains(scar)': False,
#   'contains(mah)': False,
#   'contains(loud)': False,
#   'contains(gent)': False,
#   'contains(contact)': False,
#   'contains(last)': False,
#   'contains(draw)': False,
#   'contains(09064012160.)': False,
#   'contains(k52)': False,
#   'contains(12hrs)': False,
#   'contains(150ppm)': False,
#   'contains(openin)': False,
#   'contains(sentence)': False,
#   'contains(formal)': False,
#   'contains(anyway)': False,
#   'contains(juz)': False,
#   'contains(eatin)': False,
#   'contains(puttin)': False,
#   'contains(weight)': False,
#   'contains(haha)': False,
#   'contains(anythin)': False,
#   'contains(happen)': False,
#   'contains(enter)': False,
#   'contains(cabin)': False,
#   "contains(b'day)": False,
#   'contains(boss)': False,
#   'contains(felt)': False,
#   'contains(askd)': False,
#   'contains(apartment)': False,
#   'contains(specially)': False,
#   'contains(holiday)': False,
#   'contains(flight)': False,
#   'contains(inc)': False,
#   'contains(operator)': False,
#   'contains(0871277810910p/min)': False,
#   'contains(18+)': False,
#   'contains(goodo)': False,
#   'contains(must)': False,
#   'contains(friday)': False,
#   'contains(egg-potato)': False,
#   'contains(ratio)': False,
#   'contains(tortilla)': False,
#   'contains(hmm)': False,
#   'contains(uncle)': False,
#   'contains(inform)': False,
#   'contains(school)': False,
#   'contains(directly)': False,
#   'contains(food)': False,
#   'contains(private)': False,
#   'contains(2004)': False,
#   'contains(account)': False,
#   'contains(statement)': False,
#   'contains(07742676969)': False,
#   'contains(786)': False,
#   'contains(unredeemed)': False,
#   'contains(08719180248)': False,
#   'contains(identifier)': False,
#   'contains(45239)': False,
#   'contains(expire)': False,
#   'contains(£2000)': False,
#   'contains(caller)': False,
#   'contains(5/9/03)': False,
#   'contains(landline)': False,
#   'contains(09064019788)': False,
#   'contains(box42wr29c)': False,
#   'contains(-apples)': False,
#   'contains(pair)': False,
#   'contains(malarky)': False,
#   'contains(todays)': False,
#   'contains(voda)': False,
#   'contains(number)': False,
#   'contains(7548)': False,
#   'contains(350)': False,
#   'contains(match)': False,
#   'contains(08712300220)': False,
#   'contains(quote)': False,
#   'contains(4041)': False,
#   'contains(standard)': False,
#   'contains(rat)': False,
#   'contains(app)': False,
#   'contains(sao)': False,
#   'contains(predict)': False,
#   'contains(yetunde)': False,
#   'contains(bother)': False,
#   'contains(involve)': False,
#   'contains(impose)': False,
#   'contains(apologise)': False,
#   'contains(girl)': False,
#   'contains(del)': False,
#   'contains(bak)': False,
#   'contains(sum)': False,
#   'contains(lucyxx)': False,
#   'contains(tmorrow.pls)': False,
#   'contains(accomodate)': False,
#   'contains(answer)': False,
#   'contains(sunshine)': False,
#   'contains(quiz)': False,
#   'contains(top)': False,
#   'contains(sony)': False,
#   'contains(dvd)': False,
#   'contains(player)': False,
#   'contains(country)': False,
#   'contains(algarve)': False,
#   'contains(ansr)': False,
#   'contains(82277)': False,
#   'contains(tyrone)': False,
#   'contains(lay)': False,
#   'contains(dog)': False,
#   'contains(locations)': False,
#   'contains(direct)': False,
#   'contains(join)': False,
#   'contains(largest)': False,
#   'contains(txting)': False,
#   'contains(gravel)': False,
#   'contains(69888)': False,
#   'contains(ec2a)': False,
#   'contains(31p.msg)': False,
#   'contains(150p)': False,
#   'contains(haf)': False,
#   'contains(msn)': False,
#   'contains(yijue)': False,
#   'contains(hotmail.com)': False,
#   'contains(befor)': False,
#   'contains(activities)': False,
#   'contains(msgs)': False,
#   'contains(chat)': False,
#   'contains(svc)': False,
#   'contains(hardcore)': False,
#   'contains(69988)': False,
#   'contains(age)': False,
#   'contains(lazy)': False,
#   'contains(type)': False,
#   'contains(lect)': False,
#   'contains(pouch)': False,
#   'contains(sir)': False,
#   'contains(mail)': False,
#   'contains(swt)': False,
#   'contains(nver)': False,
#   'contains(tire)': False,
#   'contains(little)': False,
#   'contains(lovable)': False,
#   'contains(persons..)': False,
#   'contains(coz..somtimes)': False,
#   'contains(occupy)': False,
#   'contains(biggest)': False,
#   'contains(hearts..)': False,
#   'contains(gud)': False,
#   'contains(ni8)': False,
#   'contains(open)': False,
#   'contains(dot)': False,
#   'contains(whats)': False,
#   'contains(staff)': False,
#   'contains(randy)': False,
#   'contains(sexy)': False,
#   'contains(female)': False,
#   'contains(local)': False,
#   'contains(luv)': False,
#   'contains(netcollex)': False,
#   'contains(ltd)': False,
#   'contains(08700621170150p)': False,
#   'contains(ummma.will)': False,
#   'contains(in.our)': False,
#   'contains(begin)': False,
#   'contains(qatar)': False,
#   'contains(pray)': False,
#   'contains(hard)': False,
#   'contains(k..i)': False,
#   'contains(delete)': False,
#   'contains(sindu)': False,
#   'contains(birla)': False,
#   'contains(soft)': False,
#   'contains(wine)': False,
#   'contains(flow)': False,
#   'contains(nevering..)': False,
#   'contains(thk)': False,
#   'contains(plaza)': False,
#   'contains(typical)': False,
#   'contains(everywhere)': False,
#   'contains(dirt)': False,
#   'contains(floor)': False,
#   'contains(windows)': False,
#   'contains(shirt)': False,
#   'contains(sometimes)': False,
#   'contains(mouth)': False,
#   'contains(dream)': False,
#   'contains(without)': False,
#   'contains(chores)': False,
#   'contains(joy)': False,
#   'contains(i.ll)': False,
#   'contains(exist)': False,
#   'contains(hail)': False,
#   'contains(mist)': False,
#   'contains(become)': False,
#   'contains(aaooooright)': False,
#   'contains(house)': False,
#   'contains(interview)': False,
#   'contains(boy)': False,
#   'contains(annoncement)': False,
#   'contains(years)': False,
#   'contains(07046744435)': False,
#   'contains(arrange)': False,
#   'contains(0871277810810)': False,
#   'contains(safe)': False,
#   'contains(envy)': False,
#   'contains(everyone)': False,
#   'contains(parent)': False,
#   'contains(hand)': False,
#   'contains(excite)': False,
#   'contains(day)': False,
#   'contains(-pls)': False,
#   'contains(bootydelious)': False,
#   'contains(32/f)': False,
#   'contains(friend)': False,
#   'contains(yes-434)': False,
#   'contains(no-434)': False,
#   'contains(www.sms.ac/u/bootydelious)': False,
#   'contains(frnd)': False,
#   'contains(62468)': False,
#   'contains(bangbabes)': False,
#   'contains(order)': False,
#   'contains(content)': False,
#   'contains(goto)': False,
#   'contains(bangb)': False,
#   'contains(internet/service)': False,
#   'contains(menu)': False,
#   'contains(culture)': False,
#   'contains(module)': False,
#   'contains(09061701939.)': False,
#   'contains(s89)': False,
#   'contains(avoid)': False,
#   'contains(missunderstding)': False,
#   'contains(wit)': False,
#   'contains(beloved)': False,
#   'contains(escape)': False,
#   'contains(fancy)': False,
#   'contains(bridge)': False,
#   'contains(lager)': False,
#   'contains(completely)': False,
#   'contains(form)': False,
#   'contains(clark)': False,
#   'contains(also)': False,
#   'contains(utter)': False,
#   'contains(waste)': False,
#   'contains(axis)': False,
#   'contains(bank)': False,
#   'contains(hmmm..)': False,
#   'contains(hop)': False,
#   'contains(muz)': False,
#   'contains(discuss)': False,
#   'contains(liao)': False,
#   'contains(bloody)': False,
#   'contains(hell)': False,
#   'contains(cant)': False,
#   'contains(believe)': False,
#   'contains(surname)': False,
#   'contains(ill)': False,
#   'contains(clue)': False,
#   'contains(spanish)': False,
#   'contains(bath)': False,
#   'contains(carlos)': False,
#   'contains(mall)': False,
#   'contains(stay)': False,
#   'contains(til)': False,
#   'contains(smoke)': False,
#   'contains(worth)': False,
#   'contains(doesnt)': False,
#   'contains(log)': False,
#   'contains(maneesha)': False,
#   'contains(satisfy)': False,
#   'contains(experience)': False,
#   'contains(toll)': False,
#   'contains(lift)': False,
#   'contains(especially)': False,
#   'contains(approach)': False,
#   'contains(study)': False,
#   'contains(anyways)': False,
#   'contains(gr8)': False,
#   'contains(trust)': False,
#   'contains(ok.)': False,
#   'contains(guy)': False,
#   'contains(great.bye)': False,
#   'contains(handsome)': False,
#   'contains(towards)': False,
#   'contains(net)': False,
#   'contains(mummy)': False,
#   'contains(boytoy)': False,
#   'contains(awesome)': False,
#   'contains(minute)': False,
#   'contains(freephone)': False,
#   'contains(0808)': False,
#   'contains(145)': False,
#   'contains(4742)': False,
#   'contains(9am-11pm)': False,
#   'contains(xmas)': False,
#   'contains(radio)': False,
#   'contains(jus)': False,
#   'contains(bathe)': False,
#   'contains(sis)': False,
#   'contains(unique)': False,
#   'contains(30th)': False,
#   'contains(august)': False,
#   'contains(www.areyouunique.co.uk)': False,
#   'contains(league)': False,
#   'contains(touch)': False,
#   'contains(deal)': False,
#   'contains(personal)': False,
#   'contains(week.|)': False,
#   'contains(finally)': False,
#   'contains(complete)': False,
#   'contains(course)': False,
#   'contains(however)': False,
#   'contains(suggest)': False,
#   'contains(able)': False,
#   'contains(ors)': False,
#   'contains(every)': False,
#   'contains(stool)': False,
#   'contains(settle)': False,
#   'contains(wishin)': False,
#   'contains(mrng)': False,
#   'contains(hav)': False,
#   'contains(persons)': False,
#   'contains(story)': False,
#   'contains(hamster)': False,
#   'contains(dead)': False,
#   'contains(tmr)': False,
#   'contains(1pm)': False,
#   'contains(orchard)': False,
#   'contains(mrt)': False,
#   'contains(kate)': False,
#   'contains(babyjontet)': False,
#   'contains(enc)': False,
#   'contains(buck)': False,
#   'contains(darlin)': False,
#   'contains(ive)': False,
#   'contains(college)': False,
#   'contains(refill)': False,
#   'contains(successfully)': False,
#   'contains(inr)': False,
#   'contains(decimal)': False,
#   'contains(keralacircle)': False,
#   'contains(prepay)': False,
#   'contains(balance)': False,
#   'contains(transaction)': False,
#   'contains(goodmorning)': False,
#   'contains(sleep)': False,
#   'contains(alter)': False,
#   'contains(dat)': False,
#   'contains(ericsson)': False,
#   'contains(oso)': False,
#   'contains(oredi)': False,
#   'contains(dats)': False,
#   'contains(straight)': False,
#   'contains(dogg)': False,
#   'contains(connection)': False,
#   'contains(refund)': False,
#   'contains(bill)': False,
#   'contains(shoot)': False,
#   'contains(big)': False,
#   'contains(ready)': False,
#   'contains(bruv)': False,
#   'contains(break)': False,
#   'contains(semester)': False,
#   'contains(noe)': False,
#   'contains(leh)': False,
#   'contains(sound)': False,
#   'contains(head)': False,
#   'contains(prediction)': False,
#   'contains(past)': False,
#   'contains(nights)': False,
#   'contains(easy)': False,
#   'contains(sen)': False,
#   'contains(good..)': False,
#   'contains(exam)': False,
#   'contains(march)': False,
#   'contains(atm)': False,
#   'contains(register)': False,
#   'contains(ubandu)': False,
#   'contains(instal)': False,
#   'contains(disk)': False,
#   'contains(important)': False,
#   'contains(file)': False,
#   'contains(system)': False,
#   'contains(repair)': False,
#   'contains(shop..)': False,
#   'contains(romantic)': False,
#   'contains(nite)': False,
#   'contains(scenery)': False,
#   'contains(500)': False,
#   ...},
#  'ham')

# %%
#print(training_set[0])

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the test set
#print(nltk.classify.accuracy(spamClassifier, training_set))

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.979372197309417

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
n = '''Exams are just a way to test your child's level of understanding and ability to answer questions in a timed environment.

Cuemath's Workbooks for Grades KG-8 are designed by curriculum experts from IIT & Cambridge University to

Strengthen math concepts
Handle all Question formats
Prepare for exams
This exam season might be over but you can help your child be ready for the next. Use the code EXAMS20 to get a 20% OFF + 30% OFF on math workbooks from India's #1 math program'''

# %%
p = '''Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's'''

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS...! receive I charge only $1000 dollars prize but I am free free free free for you darling,Valid 12 hours only '
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(10))
# Out:
# Most Informative Features
#         contains(urgent) = True             spam : ham    =    189.7 : 1.0
#        contains(service) = True             spam : ham    =    103.2 : 1.0
#          contains(nokia) = True             spam : ham    =    101.0 : 1.0
#           contains(code) = True             spam : ham    =     95.9 : 1.0
#          contains(await) = True             spam : ham    =     91.7 : 1.0
#        contains(attempt) = True             spam : ham    =     78.9 : 1.0
#           contains(rate) = True             spam : ham    =     78.9 : 1.0
#            contains(txt) = True             spam : ham    =     77.7 : 1.0
#           contains(draw) = True             spam : ham    =     64.9 : 1.0
#       contains(landline) = True             spam : ham    =     62.7 : 1.0
# None

# %% [markdown]
# We’ve got an excellent accuracy of 98% on the test set. Although this is an excellent accuracy, you could further improve it by trying other models.
#
#
#
# Note that, Krishna has created a bag-of-words representation that’s created from scratch without using the CountVectorizer() function. He has used a binary representation instead of using the number of features to represent each word. In this bag-of-words table, ‘1’ means the word is present whereas ‘0’ means the absence of that word in that document. You can do this by setting the ‘binary’ parameter to ‘True’ in the CountVectorizer() function.
#
#
#
# You also saw that Krishna used the pickle library to save the model. After creating models, they are saved using the pickle library on the disk. This way, you can even send the models to be used on a different computer or platform.
#
#
#
#
# The steps that you just saw should convince you that to get excellent results, you need to take extra care of the nuances of the dataset you’re working on. You need to understand the data inside-out to take these steps because these can’t be generalised to every text classifier or even other spam datasets.

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
