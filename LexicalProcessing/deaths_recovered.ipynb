# %%
import urllib.request
import json
import pickle

# %%
url_str = 'https://api.covid19india.org/deaths_recoveries.json'

# %%
with urllib.request.urlopen(url_str) as response:
    data = response.read()

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'deaths_recoveries': [{'agebracket': '',
#    'city': '',
#    'date': '13/03/2020',
#    'district': '',
#    'gender': '',
#    'nationality': '',
#    'notes': 'KA-P6',
#    'patientnumbercouldbemappedlater': 'P74',
#    'patientstatus': 'Deceased',
#    'slno': '59',
#    'source1': 'Opening Data as of Mar 29',
#    'source2': '',
#    'source3': '',
#    'state': 'Karnataka',
#    'statecode': 'KA'},
#   {'agebracket': '',
#    'city': '',
#    'date': '20/03/2020',
#    'district': '',
#    'gender': '',
#    'nationality': '',
#    'notes': 'KA-P5',
#    'patientnumbercouldbemappedlater': '',
#    'patientstatus': 'Recovered',
#    'slno': '54',
#    'source1': 'Opening Data as of Mar 29',
#    'source2': '',
#    'source3': '',
#    'state': 'Karnataka',
#    'statecode': 'KA'},
#   {'agebracket': '',
#    'city': '',
#    'date': '24/03/2020',
#    'district': '',
#    'gender': '',
#    'nationality': '',
#    'notes': 'KA-P2',
#    'patientnumbercouldbemappedlater': '',
# ...

# %%
comp_data = data['deaths_recoveries']
output = pd.DataFrame()

# %%
import pandas as pd

# %%
type(comp_data)
# Out:
# list

# %%
for i in comp_data:
    output = output.append(i, ignore_index=True)
    #print(i)
    #break

# %%
output.describe()
# Out:
#        agebracket  city        date district gender nationality notes  \
# count        7408  7408        7408     7408   7408        7408  7408
# unique         77    78          34      214      4           3   386
# top                      21/04/2020
# freq         6973  7239         756     5495   6814        7282  6540
#
#        patientnumbercouldbemappedlater patientstatus  slno source1 source2  \
# count                             7408          7408  7408    7408    7408
# unique                              62             3  7407     548     120
# top                                        Recovered    59
# freq                              7346          6523     2     896    7044
#
#        source3        state statecode
# count     7408         7408      7408
# unique      12           31        31
# top             Maharashtra        MH
# freq      7392         1530      1529

# %%
output[output['patientstatus'] == 'Deceased']
# Out:
#      agebracket      city        date     district gender nationality  \
# 0                          13/03/2020
# 1                          13/03/2020
# 5                          26/03/2020
# 6                          27/03/2020
# 9            85    Mumbai  29/03/2020       Mumbai      M
# ...         ...       ...         ...          ...    ...         ...
# 7395         55  Ghatgate  26/04/2020       Jaipur      F
# 7396         29     Patan  26/04/2020        Sikar      M
# 7397                       26/04/2020  Other State
# 7406         60            26/04/2020      Kolkata      M
# 7407         34            26/04/2020      Kolkata      M
#
#                                                   notes  \
# 0                                                 KA-P6
# 1                                                 KA-P6
# 5                                                KA-P53
# 6                                                KA-P60
# ...

# %%
output.head()
# Out:
#   agebracket city        date district gender nationality  notes  \
# 0                  13/03/2020                              KA-P6
#
#   patientnumbercouldbemappedlater patientstatus slno  \
# 0                             P74      Deceased   59
#
#                      source1 source2 source3      state statecode
# 0  Opening Data as of Mar 29                  Karnataka        KA
